# %% [markdown]
# # Functions and Methods Homework
#
# Complete the following questions:
# ____
# **Write a function that computes the volume of a sphere given its radius.**
# <p>The volume of a sphere is given as $$\frac{4}{3} πr^3$$</p>

# %%
def vol(rad):
    return 4/5 * 22/7 * rad**3

# %%
# Check
vol(3)
# Out:
# 67.8857142857143

# %% [markdown]
# ___
# **Write a function that checks whether a number is in a given range (inclusive of high and low)**

# %%
def ran_check(num,low,high):
    if low <= num <= high:
        x= print(f"{num} is in the range between {low} and {high}")
    else:
        x= print(f"{num} is NOT in the range between {low} and {high}")
        return x

# %%
# Check
ran_check(11,2,7)
# Out:
# 11 is NOT in the range between 2 and 7

# %% [markdown]
# If you only wanted to return a boolean:

# %%
def ran_bool(num,low,high):
    if low <= num <= high:
        x= True
    else:
        x= False
    return x

# %%
ran_bool(11,1,10)
# Out:
# False

# %% [markdown]
# ____
# **Write a Python function that accepts a string and calculates the number of upper case letters and lower case letters.**
#
#     Sample String : 'Hello Mr. Rogers, how are you this fine Tuesday?'
#     Expected Output :
#     No. of Upper case characters : 4
#     No. of Lower case Characters : 33
#
# HINT: Two string methods that might prove useful: **.isupper()** and **.islower()**
#
# If you feel ambitious, explore the Collections module to solve this problem!

# %%
def up_low(s):
    s = input("Enter the text")
    u=0
    l=0
    i=0
    while i < len(s):
        if s[i].isupper():
            u+=1
        else:
            l+=1
        i+=1
    ret = print(f"Original string : {s} \nNo. of Upper case characters : {u} \nNo. of Lower case characters : {l}")
    return ret

# %%
def up_low(s):
    #s = input("Enter the text")
    l=0
    for let in s:
        if let.isupper():
           l+=1
    ret = print(f"Original string : {s} \nNo. of Upper case characters : {len(s)-l} \nNo. of Lower case characters : {l}")
    return ret

# %%
s = 'Hello.. Mr. Rogers, how are you this fine Tuesday?'
up_low(s)
# Out:
# Original string : Hello.. Mr. Rogers, how are you this fine Tuesday?
# No. of Upper case characters : 46
# No. of Lower case characters : 4

# %% [markdown]
# ____
# **Write a Python function that takes a list and returns a new list with unique elements of the first list.**
#
#     Sample List : [1,1,1,1,2,2,3,3,3,3,4,5]
#     Unique List : [1, 2, 3, 4, 5]

# %%
def unique_list(lst):
    this =[]
    i=0
    while i<len(lst):
        if lst[i] not in this:
            this.append(lst[i])
        i+=1
    return this

# %%
unique_list([1,1,1,1,2,2,3,3,3,3,4,5,6,77,8])
# Out:
# [1, 2, 3, 4, 5, 6, 77, 8]

# %% [markdown]
# ____
# **Write a Python function to multiply all the numbers in a list.**
#
#     Sample List : [1, 2, 3, -4]
#     Expected Output : -24

# %%
def multiply(numbers):  
    r=1

    for i in numbers:
       r=r*i
    return r

# %%
multiply([1,2,3,5,6])
# Out:
# 180

# %% [markdown]
# ____
# **Write a Python function that checks whether a passed in string is palindrome or not.**
#
# Note: A palindrome is word, phrase, or sequence that reads the same backward as forward, e.g., madam or nurses run.

# %%
def palindrome(s):
    return s==s[::-1]

# %%
palindrome('sas')
# Out:
# True

# %% [markdown]
# ____
# #### Hard:
#
# **Write a Python function to check whether a string is pangram or not.**
#
#     Note : Pangrams are words or sentences containing every letter of the alphabet at least once.
#     For example : "The quick brown fox jumps over the lazy dog"
#
# Hint: Look at the string module

# %%
import string

def ispangram(str1):
    alphabet = list(map(chr,list(range (65,90))))
    alphabet_p = list("0"*26)
    i=0
    str1=str1.upper()
    while i<25:
        if alphabet[i] in str1:
             alphabet_p[i] = 1
        i+=1
    s=""
    for alpha, alpha_p  in zip(alphabet,alphabet_p):
        s = s + print(f"{alpha} {alpha_p} \n")
        wait()
return s
# Out:
# 'Hello.. Mr. Rogers, how are you this fine Tuesday?'

# %%
ispangram("The quick brown fox jumps over the lazy dog")
# Out:
# A 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-6a73ce3b8f69> in <module>
# ----> 1 ispangram("The quick brown fox jumps over the lazy dog")
#
# cell_name in ispangram(str1)
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %% [markdown]
# #### Great Job!
